# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.integrate import odeint

import pybel as pb
from pybel.examples import sialic_acid_graph as sag
from pybel.io.jupyter import to_jupyter

import time
import csv

import torch
import pyro

pyro.set_rng_seed(101)

# %%
for item in dir(sag):
    print(item)
# Out:
# __add__
# __and__
# __class__
# __contains__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __iadd__
# __iand__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# __xor__
# _add_two_way_qualified_edge
# _add_two_way_unqualified_edge
# _adj
# _build_attr
# _describe_list
# _equivalent_node_iterator_helper
# _get_edge_attr
# _has_edge_attr
# _has_no_equivalent_edge
# _help_add_edge
# _help_add_edge_helper
# _iterate_authors
# _iterate_citations
# _modify
# _node
# _node_has_namespace_helper
# _pred
# _succ
# _warnings
# add_activates
# add_association
# add_binds
# add_causes_no_change
# add_correlation
# add_decreases
# add_dephosphorylates
# add_directly_activates
# add_directly_decreases
# add_directly_dephosphorylates
# ...

# %%
# get pyBEL graph entities
for item in sag.nodes:
    print(item)
# Out:
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# a(CHEBI:26667 ! "sialic acid")
# p(HGNC:1659 ! CD33)
# p(HGNC:1659 ! CD33, pmod(Ph))
# p(HGNC:9658 ! PTPN6)
# p(HGNC:9644 ! PTPN11)
# p(HGNC:11491 ! SYK)
# p(HGNC:17761 ! TREM2)
# p(HGNC:12449 ! TYROBP)

# %%
# get names and domains
x = pb.struct.summary.get_names(sag)
for item in x:
    print(x)
# Out:
# {'CHEBI': {'sialic acid'}, 'HGNC': {'TYROBP', 'SYK', 'TREM2', 'PTPN11', 'CD33', 'PTPN6'}, 'bel': {'phos', 'Ph'}}
# {'CHEBI': {'sialic acid'}, 'HGNC': {'TYROBP', 'SYK', 'TREM2', 'PTPN11', 'CD33', 'PTPN6'}, 'bel': {'phos', 'Ph'}}
# {'CHEBI': {'sialic acid'}, 'HGNC': {'TYROBP', 'SYK', 'TREM2', 'PTPN11', 'CD33', 'PTPN6'}, 'bel': {'phos', 'Ph'}}

# %%
# get pyBEL graph edges
for item in sag.edges:
    #print(item)
    #print(sag.edge_to_bel(item))
    print(item[0])
    print(item[1])
    print(item[2])
    print()
# Out:
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# p(HGNC:1659 ! CD33)
# 728a48159558b679221ad7ffb15af83b
#
# a(CHEBI:26667 ! "sialic acid")
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# a95c890f2460604b346e06901dc2df7f
#
# p(HGNC:1659 ! CD33)
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# d19689de67052bbfdb5a110ea145360f
#
# p(HGNC:1659 ! CD33)
# p(HGNC:1659 ! CD33, pmod(Ph))
# d2dc993e8613f89e3969ff894e861168
#
# p(HGNC:1659 ! CD33)
# p(HGNC:1659 ! CD33, pmod(Ph))
# ba008c30ed56cd8483656a3420bdfe0d
#
# p(HGNC:1659 ! CD33, pmod(Ph))
# p(HGNC:9658 ! PTPN6)
# 05f7f1737c81096e82e89c6ec02ce313
#
# p(HGNC:1659 ! CD33, pmod(Ph))
# p(HGNC:9644 ! PTPN11)
# 3de19766037675ba0572cbb2ef3a2485
#
# p(HGNC:9658 ! PTPN6)
# p(HGNC:11491 ! SYK)
# 983100b8ab6ec063addf7cb50f98f82f
#
# p(HGNC:9644 ! PTPN11)
# p(HGNC:11491 ! SYK)
# 2b3a979463182887bfc326e60c6c8b38
#
# p(HGNC:11491 ! SYK)
# p(HGNC:17761 ! TREM2)
# eb13bf6b415ffddfbc2358c4ac71468b
#
# ...

# %%
# get BEL statements out of pyBEL graph
for item in sag.edges:
    temp = sag.get_edge_data(item[0],item[1],item[2])
    print(item[0])
    print(item[1])
    print(temp['relation'])
    print()
# Out:
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# p(HGNC:1659 ! CD33)
# increases
#
# a(CHEBI:26667 ! "sialic acid")
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# partOf
#
# p(HGNC:1659 ! CD33)
# complex(a(CHEBI:26667 ! "sialic acid"), p(HGNC:1659 ! CD33))
# partOf
#
# p(HGNC:1659 ! CD33)
# p(HGNC:1659 ! CD33, pmod(Ph))
# hasVariant
#
# p(HGNC:1659 ! CD33)
# p(HGNC:1659 ! CD33, pmod(Ph))
# increases
#
# p(HGNC:1659 ! CD33, pmod(Ph))
# p(HGNC:9658 ! PTPN6)
# directlyIncreases
#
# p(HGNC:1659 ! CD33, pmod(Ph))
# p(HGNC:9644 ! PTPN11)
# directlyIncreases
#
# p(HGNC:9658 ! PTPN6)
# p(HGNC:11491 ! SYK)
# directlyDecreases
#
# p(HGNC:9644 ! PTPN11)
# p(HGNC:11491 ! SYK)
# directlyDecreases
#
# p(HGNC:11491 ! SYK)
# p(HGNC:17761 ! TREM2)
# increases
#
# p(HGNC:11491 ! SYK)
# p(HGNC:12449 ! TYROBP)
# increases

# %%
# write graph to BEL script
pb.to_bel_script(sag,'temp.txt')

# %%
# create graph from BEL script
sag2 = pb.from_bel_script('temp.txt',citation_clearing=False)

# %%
for item in dir(pb):
    print(item)
# Out:
# BELGraph
# BaseAbundance
# BaseEntity
# Manager
# Pipeline
# Query
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# canonicalize
# config
# constants
# cx
# dsl
# dump
# edge_to_bel
# examples
# exc
# exceptions
# extras
# from_bel_script
# from_bel_script_url
# from_biopax
# from_bytes
# from_cbn_jgif
# from_cx
# from_cx_file
# from_cx_gz
# from_cx_jsons
# from_database
# from_hetionet_file
# from_hetionet_gz
# from_hetionet_json
# from_hipathia_dfs
# from_hipathia_paths
# from_indra_pickle
# from_indra_statements
# from_indra_statements_json
# from_indra_statements_json_file
# from_jgif
# from_jgif_file
# from_jgif_gz
# from_jgif_jsons
# from_nodelink
# from_nodelink_file
# from_nodelink_gz
# from_nodelink_jsons
# from_pickle
# from_web
# get_hetionet
# get_version
# gpickle
# graphdati
# graphml
# hetionet
# hipathia
# indra
# io
# jgif
# language
# line_utils
# lines
# load
# manager
# neo4j
# nodelink
# parser
# ...
